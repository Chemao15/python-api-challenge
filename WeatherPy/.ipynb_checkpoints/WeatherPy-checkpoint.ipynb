# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from keys import api_key
from keys import geoapify_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 598

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
units='metric'


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units={units}'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat =  city_weather['coord']['lat']
        city_lng =  city_weather['coord']['lon']
        city_max_temp =  city_weather['main']['temp_max']
        city_humidity =  city_weather['main']['humidity']
        city_clouds =  city_weather['clouds']['all']
        city_wind =  city_weather['wind']['speed']
        city_country =  city_weather['sys']['country']
        city_date =  city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | paita
# Processing Record 2 of Set 1 | saipan
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | happy valley-goose bay
# Processing Record 5 of Set 1 | mao
# Processing Record 6 of Set 1 | colonia
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | tual
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | gaspe
# Processing Record 11 of Set 1 | howard springs
# Processing Record 12 of Set 1 | coahuayana de hidalgo
# Processing Record 13 of Set 1 | talnakh
# Processing Record 14 of Set 1 | puerto natales
# Processing Record 15 of Set 1 | san patricio
# Processing Record 16 of Set 1 | bilibino
# Processing Record 17 of Set 1 | prince rupert
# Processing Record 18 of Set 1 | grytviken
# Processing Record 19 of Set 1 | abepura
# Processing Record 20 of Set 1 | port-aux-francais
# Processing Record 21 of Set 1 | adamstown
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df =  pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          576
# Lat           576
# Lng           576
# Max Temp      576
# Humidity      576
# Cloudiness    576
# Wind Speed    576
# Country       576
# Date          576
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                   paita  -5.0892  -81.1144     21.18        86          85
# 1                  saipan  15.1355  145.7010     27.39       100         100
# 2             yellowknife  62.4560 -114.3525     18.09        72         100
# 3  happy valley-goose bay  53.3168  -60.3315     14.17        77         100
# 4                     mao  39.8885    4.2658     24.31       100          20
#
#    Wind Speed Country        Date
# 0        5.17      PE  1691982925
# 1        4.63      MP  1691982925
# 2        5.66      CA  1691982926
# 3        2.57      CA  1691982926
# 4        3.09      ES  1691982926

# %%
# Export the City_Data into a csv
route = "output_data/cities.csv"
city_data_df.to_csv(route, index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                         paita  -5.0892  -81.1144     21.18        86
# 1                        saipan  15.1355  145.7010     27.39       100
# 2                   yellowknife  62.4560 -114.3525     18.09        72
# 3        happy valley-goose bay  53.3168  -60.3315     14.17        77
# 4                           mao  39.8885    4.2658     24.31       100
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                85        5.17      PE  1691982925
# 1               100        4.63      MP  1691982925
# 2               100        5.66      CA  1691982926
# 3               100        2.57      CA  1691982926
# 4                20        3.09      ES  1691982926

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

plt.scatter(city_data_df.iloc[:,1],city_data_df.iloc[:,3],color="cadetblue", edgecolor="black")

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C) ') 
plt.grid(which='major', linestyle='-', linewidth='0.5', color='gray')  

 
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df.iloc[:,1],city_data_df.iloc[:,4],color="cadetblue", edgecolor="black")


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humiditi(%)') 
plt.grid(which='major', linestyle='-', linewidth='0.5', color='gray')  
plt.title("City Latitude vs Humidity (2023-08-13)")


    
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df.iloc[:,1],city_data_df.iloc[:,5],color="cadetblue", edgecolor="black")

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)') 
plt.grid(which='major', linestyle='-', linewidth='0.5', color='gray')  
plt.title("City Latitude vs Cloudiness (2023-08-13)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df.iloc[:,1],city_data_df.iloc[:,6],color="cadetblue", edgecolor="black")

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)') 
plt.grid(which='major', linestyle='-', linewidth='0.5', color='gray')  
plt.title("City Latitude vs Wind Speed  (2023-08-13)")

 
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x, y):
    slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
    line_eq = f'y = {round(intercept,2)} + {round(slope,2)} x'
    return line_eq

def y_predict(x,y):
    resul = linregress(x, y)
    return resul.slope, resul.intercept, resul.rvalue, resul.pvalue, resul.stderr

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.query("Lat>= 0")

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                        saipan  15.1355  145.7010     27.39       100
# 2                   yellowknife  62.4560 -114.3525     18.09        72
# 3        happy valley-goose bay  53.3168  -60.3315     14.17        77
# 4                           mao  39.8885    4.2658     24.31       100
# 5                       colonia  50.9333    6.9500     16.65        86
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1               100        4.63      MP  1691982925
# 2               100        5.66      CA  1691982926
# 3               100        2.57      CA  1691982926
# 4                20        3.09      ES  1691982926
# 5                 0        1.03      DE  1691982805

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.query("Lat < 0")

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 paita  -5.0892  -81.1144     21.18        86          85
# 7                  tual  -5.6667  132.7500     25.67        79          96
# 8               ushuaia -54.8000  -68.3000      1.81        80           0
# 10       howard springs -12.4970  131.0470     31.01        29           5
# 13       puerto natales -51.7236  -72.4875      1.07        96          69
#
#          Wind Speed Country        Date
# City_ID
# 0              5.17      PE  1691982925
# 7              9.21      ID  1691982927
# 8              1.03      AR  1691982927
# 10             2.92      AU  1691982927
# 13             2.35      CL  1691982928

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x=northern_hemi_df.iloc[:,1]
y=northern_hemi_df.iloc[:,3]
result = linear_regression(x,y)
slope, intercept, r, p, err = y_predict(x, y)
prediccion = intercept + (slope* x)
plt.plot(x, prediccion, color='r')
plt.annotate(result, (5,5), color='r', fontsize=15)
plt.scatter(x,y,color="blue", edgecolor="lightblue")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature') 
plt.show()

# %%
# Linear regression on Southern Hemisphere
x=southern_hemi_df.iloc[:,1]
y=southern_hemi_df.iloc[:,3]
result = linear_regression(x,y)
slope, intercept, r, p, err = y_predict(x, y)
prediccion = intercept + (slope* x)
plt.plot(x, prediccion, color='r')
plt.annotate(result, (-55,-5), color='r', fontsize=16)


plt.scatter(x,y,color="blue", edgecolor="lightblue")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature') 
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** There's is negative correlation in the northern ana positive in the southernrn

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x=northern_hemi_df.iloc[:,1]
y=northern_hemi_df.iloc[:,4]
result = linear_regression(x,y)
slope, intercept, r, p, err = y_predict(x, y)
prediccion = intercept + (slope* x)
plt.plot(x, prediccion, color='r')
plt.annotate(result, (0,10), color='r', fontsize=15)
plt.scatter(x,y,color="blue", edgecolor="lightblue")
plt.xlabel('Latitude')
plt.ylabel('Humidity') 
plt.show()

# %%
# Southern Hemisphere
x=southern_hemi_df.iloc[:,1]
y=southern_hemi_df.iloc[:,4]
result = linear_regression(x,y)
slope, intercept, r, p, err = y_predict(x, y)
prediccion = intercept + (slope* x)
plt.plot(x, prediccion, color='r')
plt.annotate(result, (-55,10), color='r', fontsize=15)


plt.scatter(x,y,color="blue", edgecolor="lightblue")
plt.xlabel('Latitude')
plt.ylabel('Humidity') 
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** These two linear regression look very similar

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x=northern_hemi_df.iloc[:,1]
y=northern_hemi_df.iloc[:,5]
result = linear_regression(x,y)
slope, intercept, r, p, err = y_predict(x, y)
prediccion = intercept + (slope* x)
plt.plot(x, prediccion, color='r')
plt.annotate(result, (0,10), color='r', fontsize=15)
plt.scatter(x,y,color="blue", edgecolor="lightblue")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness') 
plt.show()

# %%
# Southern Hemisphere
x=southern_hemi_df.iloc[:,1]
y=southern_hemi_df.iloc[:,5]
result = linear_regression(x,y)
slope, intercept, r, p, err = y_predict(x, y)
prediccion = intercept + (slope* x)
plt.plot(x, prediccion, color='r')
plt.annotate(result, (-55,20), color='r', fontsize=15)


plt.scatter(x,y,color="blue", edgecolor="lightblue")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness') 
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** These two linear regression look very similar

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x=northern_hemi_df.iloc[:,1]
y=northern_hemi_df.iloc[:,6]
result = linear_regression(x,y)
slope, intercept, r, p, err = y_predict(x, y)
prediccion = intercept + (slope* x)
plt.plot(x, prediccion, color='r')
plt.annotate(result, (0,12), color='r', fontsize=15)
plt.scatter(x,y,color="blue", edgecolor="lightblue")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed') 
plt.show()

# %%
# Southern Hemisphere
x=southern_hemi_df.iloc[:,1]
y=southern_hemi_df.iloc[:,6]
result = linear_regression(x,y)
slope, intercept, r, p, err = y_predict(x, y)
prediccion = intercept + (slope* x)
plt.plot(x, prediccion, color='r')
plt.annotate(result, (-55,10), color='r', fontsize=15)


plt.scatter(x,y,color="blue", edgecolor="lightblue")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed') 
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** The interception almost is the same in both linear regression
